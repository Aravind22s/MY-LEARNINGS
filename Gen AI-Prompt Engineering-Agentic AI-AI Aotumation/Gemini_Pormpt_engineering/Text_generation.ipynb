# %%
from google import genai
import os
from dotenv import load_dotenv

load_dotenv()

client = genai.Client(api_key=os.getenv("Gemini_api_key"))

for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.5-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# ...

# %%
response = client.models.generate_content(
    model="gemini-3.1-flash-lite",
    contents="How does AI work?"
)
print(response.text)
# Out:
# At its simplest level, Artificial Intelligence (AI) works by **processing massive amounts of data, finding patterns in that data, and using those patterns to make predictions or decisions.**
#
# You can think of it like teaching a human to recognize a cat. If you show a child 1,000 pictures of cats, eventually their brain learns the "features" of a cat (pointed ears, whiskers, specific eye shape). AI does the exact same thing, but instead of using a brain, it uses **mathematical models.**
#
# Here is the breakdown of how that process actually happens:
#
# ---
#
# ### 1. Data Input (The "Study Material")
# AI needs information to learn. This could be text (books, internet articles), images, numbers, or audio. The quality and quantity of this data determine how "smart" the AI becomes.
#
# ### 2. Machine Learning (The "Learning Engine")
# ...

# %%
from google.genai import types

def get_response (prompt, model="gemini-3.1-flash-lite"):
    response = client.models.generate_content(
        model = model,
        contents = prompt,
        config = types.GenerateContentConfig(
            thinking_config = types.ThinkingConfig(thinking_level = "low")
        )
    )
    
    return response.text

# %%
prompt = """ you are an experienced python developer,
```create a sample code for explain the functions in python language```
explain it to a 1st year college student who has zero knowledge in python language.
"""

outcome = get_response(prompt)
print(outcome)
# Out:
# Welcome to the world of coding! As an experienced developer, I’ll tell you a secret: **Functions are the single most important tool in a programmer's toolbox.**
#
# Think of a function like a **recipe** in a cookbook. You write the recipe once (the instructions), and then you can use it whenever you want to make that dish, without writing the instructions over and over again.
#
# Here is a simple example. Let's create a function that greets a student.
#
# ### The Sample Code
#
# ```python
# # 1. Defining the function (writing the recipe)
# def greet_student(name):
#     print("Hello, " + name + "!")
#     print("Welcome to your first Python class.")
#     print("-----------------------------------")
#
# # 2. Calling the function (using the recipe)
# greet_student("Alice")
# greet_student("Bob")
# greet_student("Charlie")
# ```
#
# ---
#
# ### Breaking it down for you:
#
# #### 1. `def` (The Keyword)
# ...

# %% [markdown]
# You can guide the behavior of Gemini models with system instructions. To do so, pass a GenerateContentConfig object.
#
# config=types.GenerateContentConfig(
#         system_instruction="You are a cat. Your name is Neko."),
#     contents="Hello there"
# )

# %% [markdown]
# #### The Gemini API supports multimodal inputs, allowing you to combine text with media files. The following example demonstrates providing an image:

# %%
from PIL import Image

def get_image_response (model="gemini-2.5-flash"):
    image_path = Image.open("instruments.jpg")
    response = client.models.generate_content(
        model = model,
        contents = [image_path, "tell me about the instrument"]
    )
    return response.text

print(get_image_response())
# Out:
# The image displays four distinct, stylized illustrations of different types of wrenches (also known as spanners in some regions), each set against a colorful background. Here's a description of each instrument:
#
# 1.  **Top-Left Quadrant (Purple Background): Adjustable Wrench**
#     *   **Description:** This is a classic adjustable wrench, often called a "Crescent wrench" (a popular brand name that became generic). It features one fixed jaw and one movable jaw, which can be adjusted by rotating a worm screw located on the head. The handle has a hole at the end for hanging.
#     *   **Function:** Used to grip and turn nuts and bolts of various sizes, as its jaw opening can be adapted. It's a versatile tool for general-purpose mechanical work.
#
# 2.  **Top-Right Quadrant (Yellow Background): Combination Wrench**
# ...
